# %%
! pip install matplotlib
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,9,18,7]
# plt.plot(x,y)
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")
# plt.title("Line-plot")
# plt.show()#show function call krte hi show krdega
# bar_graph={
#     "Category-1":10,
#     "Category-2":20,
#     "Category-3":30,
#     "Category-4":40,
# }
# plt.bar(bar_graph.keys(),bar_graph.values())
# plt.show()


# x=[1,2,3,4,5]
# y=[12,3,76,45,42]
# plt.scatter(x,y,)
# plt.title("scatter graph")
# plt.show()

# plt.pie([10,22,333],explode=[0,0,0],labels=["","","pacman"],colors=["white","white","black"])#the division of area is 1/6,2/6 and 3/6 and so on
# plt.show()
marks=[28,58,62,77,80,99,]

students=[35,30,28,25,20,15,12].reverse()
plt.hist(marks,students,color="red",edgecolor="black")
plt.show()
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
