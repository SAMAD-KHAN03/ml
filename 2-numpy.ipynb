# %%
import numpy as np
# how to create array in numpy
a=np.array([1,2,3])
# print(a)
b = np.array([[1,2,3], [4,5,2]])
# print(b)
# print(b.ndim)#this will tell the dimension of array
# print(b.shape)#[2,3] output menas two rows and 3 columns

c=np.array([True,20,"samad"])
d=np.array([True,20,"samad"],dtype=bool)#will forcefully convert each element ot bol
# print(c)
# print(d)
e=np.zeros([100,100])#will creatae a matrix of 100x100 and will fill it with zero
f=np.ones([100,100])#will creatae a matrix of 100x100 and will fill it with one
# print(e)
# print(f)
g=np.eye(3)
# print(g)#will create identity matrix of size given in the argument
h=np.full([4,5],9) #will create a matrix of size given and will fill the value with the second argument
# print(h)
i=np.arange(0,100,3) #will create a range between [0,100) with gap of 3
# print(i)
j=np.linspace(0,200,22)#divide the range [0,200] in 22 parts
# print(j)
k=np.array([1,2,3,4,5,6,7,8])
print(k[1:4])#will print elements between index [1,4) this is sharing memory mean if we write k[1:4]=1 original array elements from 1 to 3 will become 1 
# k[1:4]=1
# print(k)#if we want copy of k we should call k.copy

# k_copy=k[1:4].copy()
# print(k)
# print(k_copy)
# Out:
# [2 3 4]

# %%
# if array are of same size we can perform multple operations directly if and only if size of the arrays must be same

l=np.array([1,2,3,4])
m=np.array([5,6,7,8])
# print(l*m)
# print(l+m)
# print(l-m)

n=np.array([[1,2,3,4],[9,8,7,6]])
# print(n.flatten())

o=np.random.rand(2,3)#array of random floating point number
# print(o)
p=np.random.randint(1,30000,size=[10,8])#create an array of 10x8 and fill it with random int betwen 1,100
# print(p)
q=np.random.choice(["gillu","bittu","mannu","hazel","malli","owner","teddy"],[4,4])
print(q)
r=np.random.choice([1,2,3,6,4,5],[4,4])#will pick any number from the first argument array
# print(r)

s=np.array([100,101,102,1000,10200,141])
# print(s[s>1000])#we can perform filtering like this
# Out:
# [['hazel' 'hazel' 'bittu' 'owner']
#  ['hazel' 'malli' 'gillu' 'teddy']
#  ['bittu' 'gillu' 'hazel' 'teddy']
#  ['gillu' 'bittu' 'bittu' 'hazel']]
