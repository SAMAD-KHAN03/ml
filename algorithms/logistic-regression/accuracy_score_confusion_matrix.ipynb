# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMAD-KHAN03/ml/blob/master/algorithms/logistic-regression/accuracy_score_confusion_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import accuracy_score
y_true=

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
y_true = [0, 1, 0, 1, 0, 1]
y_pred = [0, 1, 1, 1, 0, 0]
acc=accuracy_score(y_true, y_pred)
print(acc)
cm=confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# 0.6666666666666666
# [[2 1]
#  [1 2]]
